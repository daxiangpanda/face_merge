# %%
from PIL import Image, ImageDraw
import face_recognition

src_img = "tri.jpg"
image = face_recognition.load_image_file(src_img)
pil_image = Image.fromarray(image)
d = ImageDraw.Draw(pil_image)
tri_list = [(36, 0, 17), (0, 36, 1)]
newTri_list = [(i[0],i[1],i[2],i[0]) for i in tri_list]
print(newTri_list)
for i in newTri_list:
    d.line(i)
pil_image
# Out:
# [(36, 0, 17, 36), (0, 36, 1, 0)]
# <PIL.Image.Image image mode=RGB size=1280x833 at 0x117046048>
